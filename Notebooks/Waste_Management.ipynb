# %% [markdown]
# # *Library*

# %%
#Regular EDA(Exploratory Data Analysis) & Plotting Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
from sklearn.compose import ColumnTransformer
# %matplotlib inline

# %% [markdown]
# # Data

# %%
Waste_1 = pd.read_csv('/content/2003_2017_waste.csv')
Waste_1
# Out:
#                                  waste_type  waste_disposed_of_tonne  \
# 0                                      Food                   679900
# 1                           Paper/Cardboard                   576000
# 2                                  Plastics                   762700
# 3                                       C&D                     9700
# 4                       Horticultural waste                   111500
# ..                                      ...                      ...
# 220                          Ash and sludge                   214800
# 221                                 Plastic                   763400
# 222                         Textile/Leather                   141200
# 223  Others (stones, ceramic, rubber, etc.)                   319300
# 224                                   Total                  2980000
#
#      total_waste_recycled_tonne  total_waste_generated_tonne  recycling_rate  \
# ...

# %%
Waste_2 = pd.read_csv('/content/2018_2020_waste.csv')
Waste_2
# Out:
#                                Waste Type  Total Generated ('000 tonnes)  \
# 0                Construction& Demolition                           1624
# 1                           Ferrous Metal                           1269
# 2                         Paper/Cardboard                           1054
# 3                                Plastics                            949
# 4                                    Food                            763
# 5                                    Wood                            521
# 6                           Horticultural                            320
# 7                            Ash & Sludge                            240
# 8                         Textile/Leather                            220
# 9                               Used Slag                            181
# 10                      Non-Ferrous Metal                            171
# 11                                  Glass                             64
# ...

# %%
Waste_Energy = pd.read_csv('/content/waste_energy_stat.csv')
Waste_Energy
# Out:
#   The table gives the amount of energy saved in kilowatt hour (kWh) and the amount of crude oil (barrels) by recycling 1 metric tonne (1000 kilogram)  per waste type  \
# 0    1 barrel oil is approximately 159 litres of oil
# 1                                                NaN
# 2                                           material
# 3                                       energy_saved
# 4                                    crude_oil saved
#
#    Unnamed: 1    Unnamed: 2     Unnamed: 3         Unnamed: 4  Unnamed: 5
# 0         NaN           NaN            NaN                NaN         NaN
# 1         NaN           NaN            NaN                NaN         NaN
# 2     Plastic         Glass  Ferrous Metal  Non-Ferrous Metal       Paper
# 3    5774 Kwh        42 Kwh        642 Kwh          14000 Kwh    4100 kWh
# 4  16 barrels  0.12 barrels    1.8 barrels         40 barrels  11 barrels

# %%
Waste_1['waste_type'].value_counts()
# Out:
# Paper/Cardboard                            15
# Glass                                      15
# Textile/Leather                            15
# Total                                      15
# Plastics                                   14
# Others (stones, ceramics & rubber etc)     12
# Food waste                                 11
# Scrap Tyres                                11
# Sludge                                     11
# Used Slag                                  11
# Non-ferrous Metals                         11
# Horticultural Waste                        11
# Wood/Timber                                11
# Construction Debris                        11
# Ferrous Metal                               7
# Ferrous Metals                              4
# Food                                        4
# Scrap tyres                                 4
# Used slag                                   4
# Ferrous metal                               4
# ...

# %%
Waste_2['Waste Type'].value_counts()
# Out:
# Glass                                    3
# Paper/Cardboard                          3
# Plastics                                 3
# Food                                     3
# Wood                                     3
# Horticultural                            3
# Overall                                  3
# Textile/Leather                          3
# Ferrous Metal                            2
# Others (stones, ceramic, rubber, ect)    2
# Scrap Tyres                              2
# Construction& Demolition                 2
# Non-Ferrous Metal                        2
# Used Slag                                2
# Ash & Sludge                             2
# Ferrous metal                            1
# Construction & Demolition                1
# Ash & sludge                             1
# Used slag                                1
# Non-ferrous metal                        1
# Scrap tyres                              1
# Others (stones, ceramics, etc.)          1
# ...

# %%
Waste_Cost = pd.read_csv('/content/public_data_waste_fee.csv')
Waste_Cost
# Out:
#               region               province                  name          tc  \
# 0     Emilia_Romagna                Ferrara             Comacchio  502.250000
# 1     Emilia_Romagna                Ferrara             Lagosanto  228.050003
# 2     Emilia_Romagna                Ferrara                  Goro  268.010010
# 3     Emilia_Romagna                Ferrara                Mesola  199.089996
# 4             Puglia  Barletta-Andria-Trani  Margherita di Savoia  233.639999
# ...              ...                    ...                   ...         ...
# 4336          Veneto                Vicenza                   NaN  122.500000
# 4337       Lombardia                 Varese                   NaN  126.220001
# 4338          Veneto                Belluno                   NaN   94.190002
# 4339          Veneto                Vicenza                   NaN  169.559998
# 4340          Veneto                Vicenza                   NaN   75.339996
#
# ...

# %% [markdown]
# # Waste_1

# %%
Waste_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   waste_type                   225 non-null    object
#  1   waste_disposed_of_tonne      225 non-null    int64
#  2   total_waste_recycled_tonne   225 non-null    float64
#  3   total_waste_generated_tonne  225 non-null    int64
#  4   recycling_rate               225 non-null    float64
#  5   year                         225 non-null    int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 10.7+ KB

# %%
Waste_1['waste_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
column = list(Waste_1.columns)
column.remove('waste_type')
column.remove('year')

# %%
sns.set_style("darkgrid")
sns.set('notebook')
plt.figure(figsize=(100,30))
plt.subplots_adjust(left=0.4,
                    bottom=0.3,
                    right=0.9,
                    top=0.9,
                    wspace=0.4,
                    hspace=0.6)

for i in range(0,len(column)):
#Create Subplots

  ax = plt.subplot(len(column),1,i+1)
  sns.stripplot(x='year',y=f'{column[i]}',hue='waste_type',data=Waste_1, palette='rocket')
  plt.title(f'year vs {column[i]}')
  plt.suptitle('track of recycling waste ',fontweight ="bold",fontsize='20')
  handles, labels = ax.get_legend_handles_labels()
  ax.get_legend().remove()

plt.legend(handles,labels,bbox_to_anchor =(1.1, 3.25))

plt.show()

# %%
column
# Out:
# ['waste_disposed_of_tonne',
#  'total_waste_recycled_tonne',
#  'total_waste_generated_tonne',
#  'recycling_rate']

# %%
sns.set_style("darkgrid")
sns.set('notebook')
plt.figure(figsize=(10,10))

sns.stripplot(x='year',y='waste_disposed_of_tonne',hue='waste_type',data=Waste_1, palette='rocket')
plt.title(f'year vs waste_disposed_of_tonne')
plt.legend(handles,labels,bbox_to_anchor =(1.1, 1))
plt.show()

# %%
sns.set_style("darkgrid")
sns.set('notebook')
plt.figure(figsize=(10,10))

sns.stripplot(x='year',y='total_waste_recycled_tonne',hue='waste_type',data=Waste_1, palette='rocket')
plt.title(f'year vs total_waste_recycled_tonne')
plt.legend(handles,labels,bbox_to_anchor =(1.1, 1))
plt.show()

# %%
sns.set_style("darkgrid")
sns.set('notebook')
plt.figure(figsize=(10,10))

sns.stripplot(x='year',y='total_waste_generated_tonne',hue='waste_type',data=Waste_1, palette='rocket')
plt.title(f'year vs total_waste_generated_tonne')
plt.legend(handles,labels,bbox_to_anchor =(1.1, 1))
plt.show()

# %%
sns.set_style("darkgrid")
sns.set('notebook')
plt.figure(figsize=(10,10))

sns.stripplot(x='year',y='recycling_rate',hue='waste_type',data=Waste_1, palette='rocket')
plt.title(f'year vs recycling_rate')
plt.legend(handles,labels,bbox_to_anchor =(1.1, 1))
plt.show()

# %% [markdown]
# # Waste_2

# %%
Waste_2
# Out:
#                                Waste Type  Total Generated ('000 tonnes)  \
# 0                Construction& Demolition                           1624
# 1                           Ferrous Metal                           1269
# 2                         Paper/Cardboard                           1054
# 3                                Plastics                            949
# 4                                    Food                            763
# 5                                    Wood                            521
# 6                           Horticultural                            320
# 7                            Ash & Sludge                            240
# 8                         Textile/Leather                            220
# 9                               Used Slag                            181
# 10                      Non-Ferrous Metal                            171
# 11                                  Glass                             64
# ...

# %%
Waste_2.drop([44],axis=0,inplace=True)

# %%
columns_2 = list(Waste_2.columns)
columns_2.remove('Waste Type')
columns_2.remove('Year')
columns_2
# Out:
# ["Total Generated ('000 tonnes)", "Total Recycled ('000 tonnes)"]

# %%
sns.set_style("darkgrid")
sns.set('notebook')
plt.figure(figsize=(10,10))

sns.stripplot(x='Year',y="Total Generated ('000 tonnes)",hue='Waste Type',data=Waste_2, palette='rocket')
plt.title(f'year vs Total Waste Generated')
plt.legend(handles,labels,bbox_to_anchor =(1.1, 1))
plt.show()

# %%
sns.set_style("darkgrid")
sns.set('notebook')
plt.figure(figsize=(10,10))

sns.stripplot(x='Year',y="Total Recycled ('000 tonnes)",hue='Waste Type',data=Waste_2, palette='rocket')
plt.title(f'year vs Total Waste Recycled')
plt.legend(handles,labels,bbox_to_anchor =(1.1, 1))
plt.show()

# %% [markdown]
# # Waste_Energy_Stat

# %%
Waste_Energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column                                                                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                                                                               --------------  -----
#  0   The table gives the amount of energy saved in kilowatt hour (kWh) and the amount of crude oil (barrels) by recycling 1 metric tonne (1000 kilogram)  per waste type  4 non-null      object
#  1   Unnamed: 1                                                                                                                                                           3 non-null      object
# ...

# %%
Waste_Energy.columns = [''] * len(Waste_Energy.columns)
Waste_Energy.to_csv('Waste_Energy.csv', header=False, index=False)

# %%
Waste_Energy = pd.read_csv('/content/Waste_Energy.csv')
Waste_Energy
# Out:
#   1 barrel oil is approximately 159 litres of oil  Unnamed: 1    Unnamed: 2  \
# 0                                             NaN         NaN           NaN
# 1                                        material     Plastic         Glass
# 2                                    energy_saved    5774 Kwh        42 Kwh
# 3                                 crude_oil saved  16 barrels  0.12 barrels
#
#       Unnamed: 3         Unnamed: 4  Unnamed: 5
# 0            NaN                NaN         NaN
# 1  Ferrous Metal  Non-Ferrous Metal       Paper
# 2        642 Kwh          14000 Kwh    4100 kWh
# 3    1.8 barrels         40 barrels  11 barrels

# %%
Waste_Energy = Waste_Energy.T
Waste_Energy.to_csv('Waste_Energy_1.csv', header=False, index=False)

# %%
Waste_Energy = pd.read_csv('/content/Waste_Energy_1.csv')
Waste_Energy
# Out:
#    Unnamed: 0           material energy_saved crude_oil saved
# 0         NaN            Plastic     5774 Kwh      16 barrels
# 1         NaN              Glass       42 Kwh    0.12 barrels
# 2         NaN      Ferrous Metal      642 Kwh     1.8 barrels
# 3         NaN  Non-Ferrous Metal    14000 Kwh      40 barrels
# 4         NaN              Paper     4100 kWh      11 barrels

# %%
Waste_Energy.drop('Unnamed: 0',axis=1,inplace=True)
Waste_Energy
# Out:
#             material energy_saved crude_oil saved
# 0            Plastic     5774 Kwh      16 barrels
# 1              Glass       42 Kwh    0.12 barrels
# 2      Ferrous Metal      642 Kwh     1.8 barrels
# 3  Non-Ferrous Metal    14000 Kwh      40 barrels
# 4              Paper     4100 kWh      11 barrels

# %% [markdown]
# # ***Municipal Waste INFO***

# %% [markdown]
# "Municipal waste is defined as waste collected and treated by or for municipalities. It covers waste from households, including bulky waste, similar waste from commerce and trade, office buildings, institutions and small businesses, as well as yard and garden waste, street sweepings, the contents of litter containers, and market cleansing waste if managed as household waste. The definition excludes waste from municipal sewage networks and treatment, as well as waste from construction and demolition activities. This indicator is measured in thousand tonnes and in kilograms per capita."

# %% [markdown]
# Please find below the table for columns description -
#
# *  Variable Label
# *  region Region
# *  province Province
# *  name Name of municipality
# *  tc Cost per capita eur
# *  cres residual cost per capita
# *  csor Sorted cost per caputa
# *  istat National code
# *  area km2
# *  pop population
# *  alt altitude m.s.l.
# *  isle dummy municipality on isle
# *  sea dummy coastal municipality
# *  pden population density (people per km2)
# *  wden waste per km2
# *  urb urbanization index (1 low, 3 high)
# *  fee fee scheme
# *  d_fee dmmy PAYT
# *  sample Reg with PAYT
# *  organic organic %
# *  paper paper%
# *  glass glass %
# *  wood wood %
# *  metal metal %
# *  plastic plastic %
# *  raee raee %
# *  texile texile %
# *  other other %
# *  msw_so msw sorted kg
# *  msw_un msw unsorted kg
# *  msw Municipal solid waste kg
# *  sor Share of sorther waste
# *  geo 1 South, 2 Center, 3 North
# *  roads Km of roads within the municipality
# *  s_wteregio Share of sw sent to W2E plants - regional figure
# *  s_landfill share of waste to landifil
# *  gdp Municipal revenues EUR (p) - log
# *  wage Taxable income EUR (p) - log
# *  finance Municipal revenues EUR (p) - log

# %%
Waste_Cost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4341 entries, 0 to 4340
# Data columns (total 39 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      4341 non-null   object
#  1   province    4341 non-null   object
#  2   name        4335 non-null   object
#  3   tc          4341 non-null   float64
#  4   cres        4289 non-null   float64
#  5   csor        4274 non-null   float64
#  6   istat       4341 non-null   int64
#  7   area        4335 non-null   float64
#  8   pop         4341 non-null   int64
#  9   alt         4335 non-null   float64
#  10  isle        4335 non-null   float64
#  11  sea         4335 non-null   float64
#  12  pden        4335 non-null   float64
#  13  wden        4335 non-null   float64
#  14  urb         4335 non-null   float64
#  15  fee         4341 non-null   object
#  16  d_fee       4341 non-null   int64
#  17  sample      4341 non-null   int64
#  18  organic     3829 non-null   float64
# ...

# %%
Waste_Cost['region'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
def Print_Values(dfs):
  for i in dfs.columns:
    print(i,':-')
    print('\n')
    print(dfs[f'{i}'].value_counts())
    print('\n')
    print("**********************************************************************")
    print('\n')

# %%
Waste_Cost.hist(figsize=(50,50), bins=50, color='black');

# %%
Waste_Cost.drop('isle',axis=1,inplace=True)
Waste_Cost.drop('msw_so',axis=1,inplace=True)
Waste_Cost.drop('msw_un',axis=1,inplace=True)
Waste_Cost.drop('roads',axis=1,inplace=True)
Waste_Cost.drop('sea',axis=1,inplace=True)

# %%
Waste_Cost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4341 entries, 0 to 4340
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      4341 non-null   object
#  1   province    4341 non-null   object
#  2   name        4335 non-null   object
#  3   tc          4341 non-null   float64
#  4   cres        4289 non-null   float64
#  5   csor        4274 non-null   float64
#  6   istat       4341 non-null   int64
#  7   area        4335 non-null   float64
#  8   pop         4341 non-null   int64
#  9   alt         4335 non-null   float64
#  10  pden        4335 non-null   float64
#  11  wden        4335 non-null   float64
#  12  urb         4335 non-null   float64
#  13  fee         4341 non-null   object
#  14  d_fee       4341 non-null   int64
#  15  sample      4341 non-null   int64
#  16  organic     3829 non-null   float64
#  17  paper       4316 non-null   float64
#  18  glass       4308 non-null   float64
# ...

# %%
Print_Values(Waste_Cost)
# Out:
# region :-
#
#
# Lombardia                1230
# Campania                  405
# Emilia_Romagna            308
# Veneto                    265
# Toscana                   231
# Sicilia                   212
# Lazio                     188
# Friuli_Venezia_Giulia     183
# Liguria                   179
# Calabria                  165
# Trentino_Alto_Adige       157
# Abruzzo                   155
# Puglia                    126
# Sardegna                  121
# piemonte                  114
# Marche                    103
# Molise                     70
# Basilicata                 69
# Umbria                     59
# Valle_d'Aosta               1
# Name: region, dtype: int64
#
#
# **********************************************************************
#
#
# province :-
#
#
# Bergamo     218
# Brescia     172
# Milano      131
# Bolzano     115
# Salerno     112
#            ...
# Asti          2
# Torino        1
# Treviso       1
# Vercelli      1
# Aosta         1
# ...

# %%
# RAEE Means electronics waste

# %%
Waste_Cost.drop('cres',axis=1,inplace=True)
Waste_Cost.drop('csor',axis=1,inplace=True)
Waste_Cost.drop('proads',axis=1,inplace=True)
Waste_Cost.drop('gdp',axis=1,inplace=True)
Waste_Cost.drop('wage',axis=1,inplace=True)

# %%
for i in range(len(Waste_Cost['finance'])):
  Waste_Cost.iloc[i,26] = np.exp(Waste_Cost.iloc[i,26])

Waste_Cost['pop'].fillna(Waste_Cost['pop'].mean(),inplace=True)
Waste_Cost['finance'].fillna(Waste_Cost['finance'].mean(),inplace=True)

Waste_Cost['finance_per_capita'] = Waste_Cost['finance']/Waste_Cost['pop']
Waste_Cost
# Out:
#               region               province                  name          tc  \
# 0     Emilia_Romagna                Ferrara             Comacchio  502.250000
# 1     Emilia_Romagna                Ferrara             Lagosanto  228.050003
# 2     Emilia_Romagna                Ferrara                  Goro  268.010010
# 3     Emilia_Romagna                Ferrara                Mesola  199.089996
# 4             Puglia  Barletta-Andria-Trani  Margherita di Savoia  233.639999
# ...              ...                    ...                   ...         ...
# 4336          Veneto                Vicenza                   NaN  122.500000
# 4337       Lombardia                 Varese                   NaN  126.220001
# 4338          Veneto                Belluno                   NaN   94.190002
# 4339          Veneto                Vicenza                   NaN  169.559998
# 4340          Veneto                Vicenza                   NaN   75.339996
#
# ...

# %%
Waste_Cost.drop('finance',axis=1,inplace=True)

# %%
plt.subplot(1, 2, 1)
Waste_Cost['region'].value_counts().plot(kind='bar')
plt.title('Region')

plt.subplot(1, 2, 2)
Waste_Cost['province'].value_counts().plot(kind='bar')
plt.title('Province')
# Out:
# Text(0.5, 1.0, 'Province')

# %%
Waste_Cost['province'].value_counts()
# Out:
# Bergamo     218
# Brescia     172
# Milano      131
# Bolzano     115
# Salerno     112
#            ...
# Asti          2
# Torino        1
# Treviso       1
# Vercelli      1
# Aosta         1
# Name: province, Length: 102, dtype: int64

# %%
Waste_Cost['name'].value_counts()
# Out:
# Castro                  2
# Peglio                  2
# Comacchio               1
# Galbiate                1
# Serra d'Aiello          1
#                        ..
# Robecco sul Naviglio    1
# Travagliato             1
# Misilmeri               1
# Zuccarello              1
# Livigno                 1
# Name: name, Length: 4333, dtype: int64

# %%
Waste_Cost.drop('name',axis=1,inplace=True)
Waste_Cost.drop('province',axis=1,inplace=True)
Waste_Cost.drop('pop',axis=1,inplace=True)
Waste_Cost
# Out:
#               region          tc   istat        area  alt        pden  \
# 0     Emilia_Romagna  502.250000   38006  283.750000  1.0   79.816742
# 1     Emilia_Romagna  228.050003   38011   34.439999  1.0  143.786301
# 2     Emilia_Romagna  268.010010   38025   26.620001  1.0  146.318558
# 3     Emilia_Romagna  199.089996   38014   84.300003  1.0   84.697502
# 4             Puglia  233.639999  110005   35.700001  1.0  341.540619
# ...              ...         ...     ...         ...  ...         ...
# 4336          Veneto  122.500000   24125         NaN  NaN         NaN
# 4337       Lombardia  126.220001   12143         NaN  NaN         NaN
# 4338          Veneto   94.190002   25074         NaN  NaN         NaN
# 4339          Veneto  169.559998   24127         NaN  NaN         NaN
# 4340          Veneto   75.339996   24126         NaN  NaN         NaN
#
#                wden  urb       fee  d_fee  ...    plastic      raee    texile  \
# ...

# %%
Waste_Cost.describe()
# Out:
#                 tc          istat         area          alt          pden  \
# count  4341.000000    4341.000000  4335.000000  4335.000000   4335.000000
# mean    154.235761   47469.933195    40.995045   310.052134    405.048252
# std      76.069005   30089.798169    56.784025   280.534306    771.211960
# min      25.690001    1272.000000     0.120000     1.000000      2.479942
# 25%     108.040001   18135.000000    10.850000    80.000000     62.588707
# 50%     136.619995   42015.000000    22.730000   240.000000    151.323624
# 75%     179.160004   70049.000000    47.490002   459.000000    399.364822
# max     977.419983  111107.000000  1287.390015  1816.000000  12122.826172
#
#                wden          urb        d_fee       sample      organic  ...  \
# count  4.335000e+03  4335.000000  4341.000000  4341.000000  3829.000000  ...
# mean   1.920578e+05     2.489965     0.128311     0.546879    22.275126  ...
# ...

# %%
Waste_Cost['s_wteregio'].value_counts()
# Out:
# 5.259995e+16    1196
# 1.000000e+00     627
# 1.278847e+12     367
# 2.384186e+14     304
# 1.989405e+04     256
# 1.755695e+05     221
# 3.855322e+07     182
# 6.301069e+04     161
# 1.126325e+08     156
# 2.797733e+02     141
# 7.368498e+03     110
# 5.719417e+01     109
# 4.228294e+10     107
# 1.914987e+28      64
# 2.246939e+02      55
# Name: s_wteregio, dtype: int64

# %%
Waste_Cost['region'].value_counts()
# Out:
# Lombardia                1230
# Campania                  405
# Emilia_Romagna            308
# Veneto                    265
# Toscana                   231
# Sicilia                   212
# Lazio                     188
# Friuli_Venezia_Giulia     183
# Liguria                   179
# Calabria                  165
# Trentino_Alto_Adige       157
# Abruzzo                   155
# Puglia                    126
# Sardegna                  121
# piemonte                  114
# Marche                    103
# Molise                     70
# Basilicata                 69
# Umbria                     59
# Valle_d'Aosta               1
# Name: region, dtype: int64

# %%
y=0
for i in Waste_Cost['region']:
  if i =="Valle_d'Aosta":
    print(y)
  y+=1
# Out:
# 3623

# %%
Waste_Cost.drop([3623],axis=0,inplace=True)

# %%
Waste_Cost.drop('s_wteregio',axis=1,inplace=True)

# %%
def col_trans(dfs,drop_cols,encoder_len):
  cols = list(dfs.columns)
  for i in range(0,encoder_len):
    cols.remove(i)
  dfs.columns = cols+drop_cols
  return dfs

# %%
def One_Hot(dfs,columns,drop_cols):
  #creating instance of one-hot-encoder
  encoder = OneHotEncoder(handle_unknown='ignore')

  #perform one-hot encoding on column 
  encoder_df = pd.DataFrame(encoder.fit_transform(dfs[[columns]]).toarray())
  encoder_len = len(encoder_df.columns)
  #merge one-hot encoded columns back with original DataFrame
  dfs = dfs.join(encoder_df)

  dfs.drop(columns, axis=1, inplace=True)

  return dfs,encoder_len

# %%
Region_cols = list(Waste_Cost['region'].unique())

# %%
cols = list(Waste_Cost.columns)
cols.remove('finance_per_capita')
cols.remove('region')

# %%
df_Region,len_enc_Region=One_Hot(Waste_Cost,'region',Region_cols)
df_Region= col_trans(df_Region,Region_cols,len_enc_Region)

# %%
df_Region.drop(cols,axis=1,inplace=True)

# %%
df_Region.drop('finance_per_capita', axis=1).corrwith(df_Region.finance_per_capita).plot(kind='bar', grid=True, figsize=(20, 8), title="Correlation with Different Regions",color="Black")
# Out:
# <Axes: title={'center': 'Correlation with Different Regions'}>

# %%
Waste_Cost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4340 entries, 0 to 4340
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   region              4340 non-null   object
#  1   tc                  4340 non-null   float64
#  2   istat               4340 non-null   int64
#  3   area                4334 non-null   float64
#  4   alt                 4334 non-null   float64
#  5   pden                4334 non-null   float64
#  6   wden                4334 non-null   float64
#  7   urb                 4334 non-null   float64
#  8   fee                 4340 non-null   object
#  9   d_fee               4340 non-null   int64
#  10  sample              4340 non-null   int64
#  11  organic             3829 non-null   float64
#  12  paper               4315 non-null   float64
#  13  glass               4307 non-null   float64
#  14  wood                3245 non-null   float64
# ...

# %%
for label, content in Waste_Cost.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            #Fill missing numeric valuees with median
            Waste_Cost[label] = content.fillna(content.median())

# %%
for label, content in Waste_Cost.items():
    if pd.api.types.is_object_dtype(content):
        if pd.isnull(content).sum():
            #Fill missing numeric valuees with median
            Waste_Cost[label] = content.fillna(content.mode())

# %%
Waste_Cost.isna().sum()
# Out:
# region                0
# tc                    0
# istat                 0
# area                  0
# alt                   0
# pden                  0
# wden                  0
# urb                   0
# fee                   0
# d_fee                 0
# sample                0
# organic               0
# paper                 0
# glass                 0
# wood                  0
# metal                 0
# plastic               0
# raee                  0
# texile                0
# other                 0
# msw                   0
# sor                   0
# geo                   0
# s_landfill            0
# finance_per_capita    0
# dtype: int64

# %%
Waste_Cost.drop('finance_per_capita', axis=1).corrwith(Waste_Cost.finance_per_capita).plot(kind='bar', grid=True, figsize=(20, 8), title="Correlation with Finance",color="Grey")
# Out:
# <Axes: title={'center': 'Correlation with Finance'}>

# %%
Waste_Cost.drop('istat',axis=1,inplace=True)
Waste_Cost.drop('d_fee',axis=1,inplace=True)
Waste_Cost.drop('sample',axis=1,inplace=True)
Waste_Cost.drop('organic',axis=1,inplace=True)
Waste_Cost.drop('s_landfill',axis=1,inplace=True)
Waste_Cost.drop('geo',axis=1,inplace=True)
Waste_Cost.drop('msw',axis=1,inplace=True)

# %%
Waste_Cost['fee'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
Waste_Cost.hist(figsize=(50,50), bins=50, color='grey');

# %%
corr_matrix = Waste_Cost.corr()
fig , ax = plt.subplots(figsize=(100,50))
ax = sns.heatmap(corr_matrix,
                annot=True,
                linewidths=0.5,
                fmt='.2f')

# %% [markdown]
# ### **Train Test Split**

# %%
Y = Waste_Cost['finance_per_capita']
Waste_Cost.drop('finance_per_capita',axis=1,inplace=True)

X_train, X_test, Y_train, Y_test = train_test_split(Waste_Cost,Y,test_size=0.2,random_state=42,stratify=Waste_Cost['urb'])

# %%
Waste_Cost.hist(figsize=(50,50), bins=50, color='Blue');

# %%
columns = list(X_train.columns)
columns.remove('region')
columns.remove('fee')

# %%
ct = ct = make_column_transformer(
    (MinMaxScaler(), columns),
    (OneHotEncoder(handle_unknown='ignore'),['region','fee']))

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3472 entries, 357 to 76
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   region   3472 non-null   object
#  1   tc       3472 non-null   float64
#  2   area     3472 non-null   float64
#  3   alt      3472 non-null   float64
#  4   pden     3472 non-null   float64
#  5   wden     3472 non-null   float64
#  6   urb      3472 non-null   float64
#  7   fee      3472 non-null   object
#  8   paper    3472 non-null   float64
#  9   glass    3472 non-null   float64
#  10  wood     3472 non-null   float64
#  11  metal    3472 non-null   float64
#  12  plastic  3472 non-null   float64
#  13  raee     3472 non-null   float64
#  14  texile   3472 non-null   float64
#  15  other    3472 non-null   float64
#  16  sor      3472 non-null   float64
# dtypes: float64(15), object(2)
# memory usage: 488.2+ KB

# %%
X_train['region'].value_counts()
# Out:
# Lombardia                978
# Campania                 338
# Emilia_Romagna           248
# Veneto                   199
# Toscana                  185
# Sicilia                  165
# Lazio                    152
# Friuli_Venezia_Giulia    143
# Liguria                  141
# Calabria                 136
# Trentino_Alto_Adige      127
# Abruzzo                  125
# Puglia                   101
# Sardegna                  95
# piemonte                  94
# Marche                    82
# Molise                    59
# Basilicata                55
# Umbria                    49
# Name: region, dtype: int64

# %%
X_train['fee'].value_counts()
# Out:
# STANDARD    3024
# PAYT         448
# Name: fee, dtype: int64

# %%
ct.fit(X_train)
X_train_ct = ct.transform(X_train)
X_test_ct = ct.transform(X_test)

# %%
#Set Random Seed
tf.random.set_seed(42)

#Create the model
model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(12,activation='relu'),
    tf.keras.layers.Dense(30,activation='relu'),
    tf.keras.layers.Dense(60,activation='relu'),
    tf.keras.layers.Dense(90,activation='relu'),
    tf.keras.layers.Dense(100,activation='relu'),
    tf.keras.layers.Dense(100,activation='relu'),
    tf.keras.layers.Dense(90,activation='relu'),
    tf.keras.layers.Dense(60,activation='relu'),
    tf.keras.layers.Dense(30,activation='relu'),
    tf.keras.layers.Dense(1)
])

#Compile the Model
model_1.compile(
    loss=tf.keras.losses.mae, 
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), 
    metrics=['mae']
)

#Creating a CallBack
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-4 * 10**(epoch/20))

#Fit the Model
history=model_1.fit(X_train_ct, Y_train, epochs=200,callbacks=[lr_scheduler])
# Out:
# Epoch 1/200
# 109/109 [==============================] - 2s 3ms/step - loss: 0.0034 - mae: 0.0034 - lr: 1.0000e-04
# Epoch 2/200
# 109/109 [==============================] - 0s 4ms/step - loss: 0.0031 - mae: 0.0031 - lr: 1.1220e-04
# Epoch 3/200
# 109/109 [==============================] - 0s 4ms/step - loss: 0.0031 - mae: 0.0031 - lr: 1.2589e-04
# Epoch 4/200
# 109/109 [==============================] - 0s 4ms/step - loss: 0.0030 - mae: 0.0030 - lr: 1.4125e-04
# Epoch 5/200
# 109/109 [==============================] - 0s 4ms/step - loss: 0.0030 - mae: 0.0030 - lr: 1.5849e-04
# Epoch 6/200
# 109/109 [==============================] - 0s 4ms/step - loss: 0.0030 - mae: 0.0030 - lr: 1.7783e-04
# Epoch 7/200
# 109/109 [==============================] - 0s 4ms/step - loss: 0.0030 - mae: 0.0030 - lr: 1.9953e-04
# Epoch 8/200
# 109/109 [==============================] - 0s 2ms/step - loss: 0.0029 - mae: 0.0029 - lr: 2.2387e-04
# Epoch 9/200
# ...

# %%
#Set Random Seed
tf.random.set_seed(42)

#Create the model
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(12,activation='relu'),
    tf.keras.layers.Dense(30,activation='relu'),
    tf.keras.layers.Dense(60,activation='relu'),
    tf.keras.layers.Dense(90,activation='relu'),
    tf.keras.layers.Dense(100,activation='softsign'),
    tf.keras.layers.Dense(100,activation='tanh'),
    tf.keras.layers.Dense(90,activation='relu'),
    tf.keras.layers.Dense(60,activation='relu'),
    tf.keras.layers.Dense(30,activation='relu'),
    tf.keras.layers.Dense(1)
])

#Compile the Model
model_2.compile(
    loss=tf.keras.losses.mae, 
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0010), 
    metrics=['mae']
)

#Fit the Model
history_2=model_2.fit(X_train_ct, Y_train, epochs=200)
# Out:
# Epoch 1/200
# 109/109 [==============================] - 2s 2ms/step - loss: 0.0049 - mae: 0.0049
# Epoch 2/200
# 109/109 [==============================] - 0s 3ms/step - loss: 0.0036 - mae: 0.0036
# Epoch 3/200
# 109/109 [==============================] - 0s 2ms/step - loss: 0.0031 - mae: 0.0031
# Epoch 4/200
# 109/109 [==============================] - 0s 3ms/step - loss: 0.0030 - mae: 0.0030
# Epoch 5/200
# 109/109 [==============================] - 0s 4ms/step - loss: 0.0030 - mae: 0.0030
# Epoch 6/200
# 109/109 [==============================] - 0s 4ms/step - loss: 0.0029 - mae: 0.0029
# Epoch 7/200
# 109/109 [==============================] - 0s 4ms/step - loss: 0.0028 - mae: 0.0028
# Epoch 8/200
# 109/109 [==============================] - 0s 4ms/step - loss: 0.0028 - mae: 0.0028
# Epoch 9/200
# 109/109 [==============================] - 0s 4ms/step - loss: 0.0029 - mae: 0.0029
# Epoch 10/200
# ...

# %%
model_2.save('Waste_Fee.h5')
